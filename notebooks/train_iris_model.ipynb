# %% [markdown]
# ## Iris flower ML-Model
#
# In this demonstration we will work with the well known [Iris flower dataset](https://en.wikipedia.org/wiki/Iris_flower_data_set).
#
# The goal will be, to classify the Iris species based on some information. The Iris species we want to classify are:
# * [Iris setosa](http://upload.wikimedia.org/wikipedia/commons/5/56/Kosaciec_szczecinkowaty_Iris_setosa.jpg)
# * [Iris Versicolor](http://upload.wikimedia.org/wikipedia/commons/4/41/Iris_versicolor_3.jpg)
# * [Iris Virginica](http://upload.wikimedia.org/wikipedia/commons/9/9f/Iris_virginica.jpg)

# %% [markdown]
# ### Inspecting the data

# %%
import seaborn as sns

iris_data = sns.load_dataset("iris")
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Sepal / Petal meaning

# %%
from IPython.display import Image
url = 'https://upload.wikimedia.org/wikipedia/commons/7/78/Petal-sepal.jpg'
Image(url,width=300, height=300)

# %% [markdown]
# ### Looking for correlation in the data

# %%
#TODO: inspect the data with a Pairplot from seaborn library. Write Code here

# %%
#Don't write code here, to not overwrite the diagrams

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
#TODO: Perform a split of the data into a train-dataset and test-dataset. The test size can be 0.3 (30%)

# %% [markdown]
# ### Train the model: Support Vector Classifier

# %%
from sklearn.svm import SVC

# %%
#TODO: Create a SVC model and train it with the train dataset
# Out:
# SVC()

# %% [markdown]
# ### Evaluate the model

# %%
from sklearn.metrics import classification_report

# %%
#TODO: Create the predictions for the test-dataset using the trained model

# %%
#TODO: Show the classification report for the predictions of the model

# %%
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        13
#   versicolor       1.00      0.95      0.97        20
#    virginica       0.92      1.00      0.96        12
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# ### Persisting the model

# %%
from joblib import dump

# %%
#TODO: Dump the svc model object in order to reuse it at some other place in the code base.
# Dump it in a file located in: ../trained_models/persisted_models/
# Out:
# ['../trained_models/persisted_models/trained_iris_model.joblib']

# %%
import onnxruntime
from skl2onnx import convert_sklearn
from skl2onnx.common.data_types import FloatTensorType

# %%
# Ignore this for now
